# %%
import pandas as pd

# %%
data = pd.read_csv("https://gist.githubusercontent.com/vinaykusuma57/c663bd0a9f465740f3cdeff533b52f83/raw/global_coffee_data.csv")

# %%
data.head(11)
# Out:
#       Country  Year  Production (Metric Tons)  Consumption (Metric Tons)  \
# 0      Brazil  2023                   3700000                    1200000
# 1     Vietnam  2023                   1800000                     200000
# 2    Colombia  2023                    870000                     300000
# 3   Indonesia  2023                    660000                     280000
# 4    Ethiopia  2023                    450000                     250000
# 5      Brazil  2024                   3800000                    1250000
# 6     Vietnam  2024                   1850000                     210000
# 7    Colombia  2024                    890000                     310000
# 8   Indonesia  2024                    670000                     290000
# 9    Ethiopia  2024                    460000                     260000
# 10      India  2024                   3800000                    1300000
#
#     Export Volume (Metric Tons)  Import Volume (Metric Tons)
# ...
